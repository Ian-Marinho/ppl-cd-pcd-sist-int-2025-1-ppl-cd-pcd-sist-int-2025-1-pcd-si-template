# %% [markdown]
# <a href="https://colab.research.google.com/github/Ian-Marinho/ppl-cd-pcd-sist-int-2025-1-ppl-cd-pcd-sist-int-2025-1-pcd-si-template/blob/main/Tabela_Filtrada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import pandas as pd
#Variavel do .csv
data = pd.read_csv('Filtragem_de_Dados_Atualizada.csv')

# %%
#Renomear coluna
data = data.rename(columns={'Quantidade de cursos no estado onde mora': 'Existe faculdade no Estado'})

# %%
data
# Out:
#                                     Id  Idade Faixa idade     Gênero  \
# 0     001b2d1qtli8t9z7oqgdhj001b2d4i0g     31       30-34  Masculino
# 1     0026aa3fwd78u0026asg7456tfkjg2cs     30       30-34  Masculino
# 2     00r21rb9pusd1b0v7ew00r21rw3dy69w     37       35-39   Feminino
# 3     00urm3jf2cek12w6ygue00urm3jzd17j     22       22-24  Masculino
# 4     00v0az4g792svil00vn6y1kfm9hq8vy9     34       30-34  Masculino
# ...                                ...    ...         ...        ...
# 5288  zyg9519671iqrgy93qzyg95183k8ix5f     34       30-34  Masculino
# 5289  zyppgxzxko25qkgwsbrgpzyppgxzxs81     32       30-34  Masculino
# 5290  zysl5f50cnz3r0cbe6t2zysrxbzfsrng     25       25-29  Masculino
# 5291  zyt2656c9e1becxp457zyt26566dsng8     31       30-34  Masculino
# 5292  zzvyz3z5jy2lzzvyziv62lvtjrab9r5x     31       30-34  Masculino
#
#      Cor/raca/etnia  PCD Vive no Brasil          Estado onde mora  \
# 0            Branca  Não              1         Minas Gerais (MG)
# ...

# %%
#variavel de coluna
coluna = 'Existe faculdade no Estado'

# %%
data[coluna] = data[coluna].apply(lambda x: 1 if x != 0 else 0)

# %%
data
# Out:
#                                     Id  Idade Faixa idade     Gênero  \
# 0     001b2d1qtli8t9z7oqgdhj001b2d4i0g     31       30-34  Masculino
# 1     0026aa3fwd78u0026asg7456tfkjg2cs     30       30-34  Masculino
# 2     00r21rb9pusd1b0v7ew00r21rw3dy69w     37       35-39   Feminino
# 3     00urm3jf2cek12w6ygue00urm3jzd17j     22       22-24  Masculino
# 4     00v0az4g792svil00vn6y1kfm9hq8vy9     34       30-34  Masculino
# ...                                ...    ...         ...        ...
# 5288  zyg9519671iqrgy93qzyg95183k8ix5f     34       30-34  Masculino
# 5289  zyppgxzxko25qkgwsbrgpzyppgxzxs81     32       30-34  Masculino
# 5290  zysl5f50cnz3r0cbe6t2zysrxbzfsrng     25       25-29  Masculino
# 5291  zyt2656c9e1becxp457zyt26566dsng8     31       30-34  Masculino
# 5292  zzvyz3z5jy2lzzvyziv62lvtjrab9r5x     31       30-34  Masculino
#
#      Cor/raca/etnia  PCD Vive no Brasil          Estado onde mora  \
# 0            Branca  Não              1         Minas Gerais (MG)
# ...
